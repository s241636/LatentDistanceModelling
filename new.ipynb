# %%
# Core numerical and ML dependencies used throughout the notebook.
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets, transforms
import random
from sklearn.decomposition import PCA

# Fix every random seed so the sampled dataset, graph, and initialization are reproducible.
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Use a GPU when available because pairwise distance and graph computations can be large.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# The graph is extremely sparse, so we only sample a subset of non-edges each epoch.
# Example: 5 means "use about 5x as many sampled negatives as positives".
negative_sampling_coeff = 5 # sample this many more negatives than positives each epoch
# These are currently placeholders from earlier weighted-loss experiments.
pos_loss_weight = 1
neg_loss_weight = 1  

# Initialization of the latent positions Z.c
# PCA gives a structured 2D starting point; "None" would use random noise instead.
initialization = "PCA" # "PCA" or "None"

# Training loop controls.
num_epochs = 10000
early_stopping_patience = 200
early_stopping_min_delta = 0.0

# %%
# From here on, d means latent dimension rather than observed feature dimension.
# We force d=2 so the learned latent positions can be plotted directly.
n = A.shape[0]
d = 2
# gamma contains one learnable popularity/intercept term per node.
# A large gamma_i makes node i more likely to connect, independent of geometry.
gamma = torch.zeros(n, requires_grad=True, device=device)

if initialization == "PCA":
    # Use the top 2 principal components of X as an informed starting point for Z.
    pca = PCA(n_components=d)
    Z_init = pca.fit_transform(X.cpu().numpy())
    Z = torch.tensor(Z_init, dtype=torch.float32, device=device, requires_grad=True)
elif initialization == "None":
    # Random initialization is a weaker starting point but useful as a baseline.
    Z = (0.1 * torch.randn(n, d, device=device)).requires_grad_()



# Enumerate every unordered node pair exactly once using the upper triangle of A.
# i[t], j[t] tells us which two nodes correspond to pair index t.
i, j = torch.triu_indices(n, n, offset=1, device=device)
# pair_targets stores the observed binary edge indicator y_ij for each unordered pair.
pair_targets = torch.as_tensor(A, dtype=torch.float32, device=device)[i, j]
pos_mask = pair_targets == 1
neg_mask = pair_targets == 0

# Convert the boolean masks into pair-index lists.
# pos_idx points to true edges, neg_idx points to non-edges.
pos_idx = torch.where(pos_mask)[0].to(device)
neg_idx = torch.where(neg_mask)[0].to(device)
num_pos = int(pos_idx.numel())
num_neg_total = int(neg_idx.numel())
# Most possible pairs are negatives, so sample only a manageable subset each epoch.
num_neg_sample = min(num_neg_total, int(negative_sampling_coeff * num_pos))

print(f"positive pairs: {num_pos}, total negative pairs: {num_neg_total}, sampled negatives/epoch: {num_neg_sample}")

# Optimize both the latent coordinates Z and the node-level offsets gamma jointly.
optimizer = torch.optim.Adam([Z, gamma], lr=2e-3)

# Early stopping tracks whether the objective is still improving.
best_loss = float("inf")
epochs_since_improvement = 0

for epoch in range(num_epochs):
    optimizer.zero_grad()

    # Randomly choose a fresh mini-batch of non-edge pair indices for this epoch.
    neg_pick = torch.randint(0, num_neg_total, (num_neg_sample,), device=Z.device)
    neg_sample_idx = neg_idx[neg_pick]

    # Translate pair indices back into node indices so we can look up Z_i, Z_j, gamma_i, gamma_j.
    ipos = i[pos_idx]
    jpos = j[pos_idx]
    ineg = i[neg_sample_idx]
    jneg = j[neg_sample_idx]

    # Geometric part of the model: linked nodes should ideally move closer together,
    # while sampled non-links are encouraged to stay farther apart.
    pos_dist = torch.norm(Z[ipos] - Z[jpos], dim=1)
    neg_dist = torch.norm(Z[ineg] - Z[jneg], dim=1)

    # Convert node-level offsets into pair-level offsets by adding the two endpoints.
    # This lets each node contribute its own baseline tendency to form edges.
    gamma_pos_pair = gamma[ipos] + gamma[jpos]
    gamma_neg_pair = gamma[ineg] + gamma[jneg]

    # Poisson latent-distance model:
    #   log(lambda_ij) = gamma_i + gamma_j - ||Z_i - Z_j||
    # so larger distance lowers the Poisson rate and larger gamma raises it.
    pos_raw = gamma_pos_pair - pos_dist
    neg_raw = gamma_neg_pair - neg_dist

    pos_lambda = torch.exp(pos_raw)
    neg_lambda = torch.exp(neg_raw)

    # Combine observed edges (y=1) and sampled non-edges (y=0) into one vectorized objective.
    # Even though A is binary, the Poisson likelihood still makes sense because
    # the probability mass for y=0 and y=1 depends directly on lambda_ij.
    lambda_all = torch.cat([pos_lambda, neg_lambda], dim=0)
    y_all = torch.cat([torch.ones_like(pos_lambda), torch.zeros_like(neg_lambda)], dim=0)
    log_likelihood = (y_all * torch.log(lambda_all) - lambda_all).sum()

    # Minimize negative log-likelihood, normalized so the scale stays comparable
    # when the number of sampled negatives changes.
    loss = -log_likelihood / y_all.numel()

    loss.backward()
    # Gradient clipping helps avoid occasional unstable jumps from large exponentials.
    torch.nn.utils.clip_grad_norm_([Z, gamma], max_norm=1.0)
    optimizer.step()

    loss_value = loss.item()
    # Standard early-stopping bookkeeping.
    if loss_value < (best_loss - early_stopping_min_delta):
        best_loss = loss_value
        epochs_since_improvement = 0
    else:
        epochs_since_improvement += 1

    if (epoch + 1) % 25 == 0 or epoch == 0:
        with torch.no_grad():
            pos_mean = pos_dist.mean().item()
            neg_mean = neg_dist.mean().item()
            pos_lam_mean = pos_lambda.mean().item()
            neg_lam_mean = neg_lambda.mean().item()
        # These summaries let us see whether the embedding is separating linked and unlinked pairs.
        print(
            f"Epoch {epoch+1}/{num_epochs}, Loss: {loss_value:.4f}, "
            f"pos_d: {pos_mean:.4f}, neg_d(sampled): {neg_mean:.4f}, "
            f"pos_lambda: {pos_lam_mean:.4f}, neg_lambda: {neg_lam_mean:.4f}, "
            f"best_loss: {best_loss:.4f}"
        )

    if epochs_since_improvement >= early_stopping_patience:
        # Stop once the objective has plateaued long enough.
        print(f"Early stopping at epoch {epoch+1}")
        break

# Final learned 2D latent coordinates for all nodes.
print("Final node embeddings (Z):\n", Z.detach().cpu().numpy())
# Out:
# positive pairs: 152893, total negative pairs: 97840107, sampled negatives/epoch: 764465
# Epoch 1/10000, Loss: 0.3144, pos_d: 1.0136, neg_d(sampled): 3.7547, pos_lambda: 0.4296, neg_lambda: 0.0886, best_loss: 0.3144
# Epoch 25/10000, Loss: 0.3077, pos_d: 0.9798, neg_d(sampled): 3.7632, pos_lambda: 0.4549, neg_lambda: 0.0894, best_loss: 0.3077
# Epoch 50/10000, Loss: 0.3021, pos_d: 0.9500, neg_d(sampled): 3.7701, pos_lambda: 0.4782, neg_lambda: 0.0898, best_loss: 0.3021
# Epoch 75/10000, Loss: 0.2980, pos_d: 0.9252, neg_d(sampled): 3.7821, pos_lambda: 0.4975, neg_lambda: 0.0900, best_loss: 0.2980
# Epoch 100/10000, Loss: 0.2945, pos_d: 0.9041, neg_d(sampled): 3.7996, pos_lambda: 0.5134, neg_lambda: 0.0896, best_loss: 0.2945
# Epoch 125/10000, Loss: 0.2916, pos_d: 0.8858, neg_d(sampled): 3.8114, pos_lambda: 0.5264, neg_lambda: 0.0891, best_loss: 0.2916
# Epoch 150/10000, Loss: 0.2892, pos_d: 0.8698, neg_d(sampled): 3.8259, pos_lambda: 0.5373, neg_lambda: 0.0886, best_loss: 0.2892
# Epoch 175/10000, Loss: 0.2871, pos_d: 0.8556, neg_d(sampled): 3.8413, pos_lambda: 0.5463, neg_lambda: 0.0880, best_loss: 0.2871
# Epoch 200/10000, Loss: 0.2850, pos_d: 0.8428, neg_d(sampled): 3.8556, pos_lambda: 0.5541, neg_lambda: 0.0872, best_loss: 0.2848
# Epoch 225/10000, Loss: 0.2830, pos_d: 0.8313, neg_d(sampled): 3.8791, pos_lambda: 0.5608, neg_lambda: 0.0863, best_loss: 0.2830
# Epoch 250/10000, Loss: 0.2815, pos_d: 0.8208, neg_d(sampled): 3.8957, pos_lambda: 0.5667, neg_lambda: 0.0856, best_loss: 0.2815
# Epoch 275/10000, Loss: 0.2802, pos_d: 0.8113, neg_d(sampled): 3.9093, pos_lambda: 0.5719, neg_lambda: 0.0853, best_loss: 0.2801
# Epoch 300/10000, Loss: 0.2787, pos_d: 0.8025, neg_d(sampled): 3.9300, pos_lambda: 0.5765, neg_lambda: 0.0844, best_loss: 0.2785
# Epoch 325/10000, Loss: 0.2772, pos_d: 0.7945, neg_d(sampled): 3.9499, pos_lambda: 0.5805, neg_lambda: 0.0835, best_loss: 0.2772
# Epoch 350/10000, Loss: 0.2761, pos_d: 0.7870, neg_d(sampled): 3.9682, pos_lambda: 0.5844, neg_lambda: 0.0831, best_loss: 0.2759
# Epoch 375/10000, Loss: 0.2747, pos_d: 0.7801, neg_d(sampled): 3.9903, pos_lambda: 0.5881, neg_lambda: 0.0822, best_loss: 0.2746
# Epoch 400/10000, Loss: 0.2736, pos_d: 0.7737, neg_d(sampled): 4.0077, pos_lambda: 0.5915, neg_lambda: 0.0816, best_loss: 0.2735
# Epoch 425/10000, Loss: 0.2724, pos_d: 0.7678, neg_d(sampled): 4.0275, pos_lambda: 0.5948, neg_lambda: 0.0809, best_loss: 0.2724
# Epoch 450/10000, Loss: 0.2713, pos_d: 0.7623, neg_d(sampled): 4.0493, pos_lambda: 0.5978, neg_lambda: 0.0801, best_loss: 0.2713
# Epoch 475/10000, Loss: 0.2705, pos_d: 0.7571, neg_d(sampled): 4.0704, pos_lambda: 0.6008, neg_lambda: 0.0798, best_loss: 0.2704
# Epoch 500/10000, Loss: 0.2694, pos_d: 0.7524, neg_d(sampled): 4.0917, pos_lambda: 0.6037, neg_lambda: 0.0790, best_loss: 0.2694
# Epoch 525/10000, Loss: 0.2686, pos_d: 0.7479, neg_d(sampled): 4.1093, pos_lambda: 0.6065, neg_lambda: 0.0786, best_loss: 0.2685
# Epoch 550/10000, Loss: 0.2678, pos_d: 0.7438, neg_d(sampled): 4.1316, pos_lambda: 0.6093, neg_lambda: 0.0782, best_loss: 0.2677
# Epoch 575/10000, Loss: 0.2667, pos_d: 0.7399, neg_d(sampled): 4.1496, pos_lambda: 0.6120, neg_lambda: 0.0774, best_loss: 0.2667
# Epoch 600/10000, Loss: 0.2660, pos_d: 0.7364, neg_d(sampled): 4.1716, pos_lambda: 0.6145, neg_lambda: 0.0770, best_loss: 0.2656
# Epoch 625/10000, Loss: 0.2651, pos_d: 0.7330, neg_d(sampled): 4.1943, pos_lambda: 0.6170, neg_lambda: 0.0763, best_loss: 0.2651
# Epoch 650/10000, Loss: 0.2644, pos_d: 0.7299, neg_d(sampled): 4.2129, pos_lambda: 0.6196, neg_lambda: 0.0760, best_loss: 0.2643
# Epoch 675/10000, Loss: 0.2638, pos_d: 0.7271, neg_d(sampled): 4.2365, pos_lambda: 0.6220, neg_lambda: 0.0756, best_loss: 0.2636
# Epoch 700/10000, Loss: 0.2628, pos_d: 0.7244, neg_d(sampled): 4.2618, pos_lambda: 0.6244, neg_lambda: 0.0748, best_loss: 0.2628
# Epoch 725/10000, Loss: 0.2622, pos_d: 0.7219, neg_d(sampled): 4.2781, pos_lambda: 0.6266, neg_lambda: 0.0745, best_loss: 0.2622
# Epoch 750/10000, Loss: 0.2614, pos_d: 0.7196, neg_d(sampled): 4.3034, pos_lambda: 0.6289, neg_lambda: 0.0739, best_loss: 0.2614
# Epoch 775/10000, Loss: 0.2611, pos_d: 0.7174, neg_d(sampled): 4.3216, pos_lambda: 0.6312, neg_lambda: 0.0738, best_loss: 0.2606
# Epoch 800/10000, Loss: 0.2605, pos_d: 0.7155, neg_d(sampled): 4.3389, pos_lambda: 0.6333, neg_lambda: 0.0734, best_loss: 0.2602
# Epoch 825/10000, Loss: 0.2597, pos_d: 0.7136, neg_d(sampled): 4.3640, pos_lambda: 0.6354, neg_lambda: 0.0728, best_loss: 0.2596
# Epoch 850/10000, Loss: 0.2591, pos_d: 0.7120, neg_d(sampled): 4.3833, pos_lambda: 0.6374, neg_lambda: 0.0723, best_loss: 0.2590
# Epoch 875/10000, Loss: 0.2584, pos_d: 0.7104, neg_d(sampled): 4.4067, pos_lambda: 0.6395, neg_lambda: 0.0717, best_loss: 0.2583
# Epoch 900/10000, Loss: 0.2581, pos_d: 0.7091, neg_d(sampled): 4.4273, pos_lambda: 0.6415, neg_lambda: 0.0716, best_loss: 0.2577
# Epoch 925/10000, Loss: 0.2572, pos_d: 0.7078, neg_d(sampled): 4.4518, pos_lambda: 0.6434, neg_lambda: 0.0709, best_loss: 0.2572
# Epoch 950/10000, Loss: 0.2571, pos_d: 0.7067, neg_d(sampled): 4.4699, pos_lambda: 0.6454, neg_lambda: 0.0709, best_loss: 0.2567
# Epoch 975/10000, Loss: 0.2563, pos_d: 0.7056, neg_d(sampled): 4.4894, pos_lambda: 0.6472, neg_lambda: 0.0703, best_loss: 0.2563
# Epoch 1000/10000, Loss: 0.2559, pos_d: 0.7047, neg_d(sampled): 4.5120, pos_lambda: 0.6491, neg_lambda: 0.0700, best_loss: 0.2557
# Epoch 1025/10000, Loss: 0.2553, pos_d: 0.7039, neg_d(sampled): 4.5342, pos_lambda: 0.6508, neg_lambda: 0.0694, best_loss: 0.2552
# Epoch 1050/10000, Loss: 0.2551, pos_d: 0.7031, neg_d(sampled): 4.5508, pos_lambda: 0.6525, neg_lambda: 0.0693, best_loss: 0.2547
# Epoch 1075/10000, Loss: 0.2545, pos_d: 0.7025, neg_d(sampled): 4.5747, pos_lambda: 0.6542, neg_lambda: 0.0689, best_loss: 0.2543
# Epoch 1100/10000, Loss: 0.2540, pos_d: 0.7019, neg_d(sampled): 4.5954, pos_lambda: 0.6561, neg_lambda: 0.0684, best_loss: 0.2539
# Epoch 1125/10000, Loss: 0.2534, pos_d: 0.7015, neg_d(sampled): 4.6191, pos_lambda: 0.6578, neg_lambda: 0.0679, best_loss: 0.2533
# Epoch 1150/10000, Loss: 0.2531, pos_d: 0.7011, neg_d(sampled): 4.6378, pos_lambda: 0.6595, neg_lambda: 0.0677, best_loss: 0.2531
# Epoch 1175/10000, Loss: 0.2527, pos_d: 0.7008, neg_d(sampled): 4.6546, pos_lambda: 0.6611, neg_lambda: 0.0674, best_loss: 0.2527
# Epoch 1200/10000, Loss: 0.2523, pos_d: 0.7006, neg_d(sampled): 4.6820, pos_lambda: 0.6628, neg_lambda: 0.0671, best_loss: 0.2522
# Epoch 1225/10000, Loss: 0.2520, pos_d: 0.7004, neg_d(sampled): 4.7016, pos_lambda: 0.6644, neg_lambda: 0.0669, best_loss: 0.2517
# Epoch 1250/10000, Loss: 0.2516, pos_d: 0.7004, neg_d(sampled): 4.7167, pos_lambda: 0.6657, neg_lambda: 0.0665, best_loss: 0.2514
# Epoch 1275/10000, Loss: 0.2512, pos_d: 0.7003, neg_d(sampled): 4.7388, pos_lambda: 0.6672, neg_lambda: 0.0662, best_loss: 0.2511
# Epoch 1300/10000, Loss: 0.2506, pos_d: 0.7004, neg_d(sampled): 4.7672, pos_lambda: 0.6686, neg_lambda: 0.0655, best_loss: 0.2506
# Epoch 1325/10000, Loss: 0.2504, pos_d: 0.7005, neg_d(sampled): 4.7804, pos_lambda: 0.6701, neg_lambda: 0.0655, best_loss: 0.2504
# Epoch 1350/10000, Loss: 0.2503, pos_d: 0.7006, neg_d(sampled): 4.7965, pos_lambda: 0.6716, neg_lambda: 0.0654, best_loss: 0.2500
# Epoch 1375/10000, Loss: 0.2499, pos_d: 0.7008, neg_d(sampled): 4.8178, pos_lambda: 0.6731, neg_lambda: 0.0651, best_loss: 0.2497
# Epoch 1400/10000, Loss: 0.2496, pos_d: 0.7011, neg_d(sampled): 4.8385, pos_lambda: 0.6745, neg_lambda: 0.0648, best_loss: 0.2494
# Epoch 1425/10000, Loss: 0.2492, pos_d: 0.7014, neg_d(sampled): 4.8590, pos_lambda: 0.6757, neg_lambda: 0.0644, best_loss: 0.2491
# Epoch 1450/10000, Loss: 0.2490, pos_d: 0.7018, neg_d(sampled): 4.8791, pos_lambda: 0.6770, neg_lambda: 0.0643, best_loss: 0.2488
# Epoch 1475/10000, Loss: 0.2486, pos_d: 0.7021, neg_d(sampled): 4.8992, pos_lambda: 0.6783, neg_lambda: 0.0639, best_loss: 0.2485
# Epoch 1500/10000, Loss: 0.2483, pos_d: 0.7026, neg_d(sampled): 4.9244, pos_lambda: 0.6796, neg_lambda: 0.0636, best_loss: 0.2482
# Epoch 1525/10000, Loss: 0.2481, pos_d: 0.7031, neg_d(sampled): 4.9346, pos_lambda: 0.6809, neg_lambda: 0.0635, best_loss: 0.2478
# Epoch 1550/10000, Loss: 0.2477, pos_d: 0.7035, neg_d(sampled): 4.9558, pos_lambda: 0.6824, neg_lambda: 0.0632, best_loss: 0.2475
# Epoch 1575/10000, Loss: 0.2472, pos_d: 0.7041, neg_d(sampled): 4.9813, pos_lambda: 0.6835, neg_lambda: 0.0626, best_loss: 0.2472
# Epoch 1600/10000, Loss: 0.2472, pos_d: 0.7046, neg_d(sampled): 4.9964, pos_lambda: 0.6847, neg_lambda: 0.0627, best_loss: 0.2471
# Epoch 1625/10000, Loss: 0.2470, pos_d: 0.7052, neg_d(sampled): 5.0118, pos_lambda: 0.6859, neg_lambda: 0.0625, best_loss: 0.2468
# Epoch 1650/10000, Loss: 0.2466, pos_d: 0.7058, neg_d(sampled): 5.0331, pos_lambda: 0.6871, neg_lambda: 0.0621, best_loss: 0.2464
# Epoch 1675/10000, Loss: 0.2464, pos_d: 0.7065, neg_d(sampled): 5.0527, pos_lambda: 0.6885, neg_lambda: 0.0619, best_loss: 0.2462
# Epoch 1700/10000, Loss: 0.2462, pos_d: 0.7072, neg_d(sampled): 5.0714, pos_lambda: 0.6894, neg_lambda: 0.0618, best_loss: 0.2460
# Epoch 1725/10000, Loss: 0.2459, pos_d: 0.7079, neg_d(sampled): 5.0894, pos_lambda: 0.6906, neg_lambda: 0.0615, best_loss: 0.2457
# Epoch 1750/10000, Loss: 0.2459, pos_d: 0.7086, neg_d(sampled): 5.1087, pos_lambda: 0.6918, neg_lambda: 0.0615, best_loss: 0.2455
# Epoch 1775/10000, Loss: 0.2452, pos_d: 0.7093, neg_d(sampled): 5.1310, pos_lambda: 0.6928, neg_lambda: 0.0608, best_loss: 0.2452
# Epoch 1800/10000, Loss: 0.2455, pos_d: 0.7101, neg_d(sampled): 5.1400, pos_lambda: 0.6939, neg_lambda: 0.0612, best_loss: 0.2450
# Epoch 1825/10000, Loss: 0.2450, pos_d: 0.7109, neg_d(sampled): 5.1650, pos_lambda: 0.6951, neg_lambda: 0.0606, best_loss: 0.2448
# Epoch 1850/10000, Loss: 0.2448, pos_d: 0.7117, neg_d(sampled): 5.1805, pos_lambda: 0.6961, neg_lambda: 0.0605, best_loss: 0.2445
# Epoch 1875/10000, Loss: 0.2444, pos_d: 0.7126, neg_d(sampled): 5.1999, pos_lambda: 0.6973, neg_lambda: 0.0601, best_loss: 0.2443
# Epoch 1900/10000, Loss: 0.2442, pos_d: 0.7135, neg_d(sampled): 5.2191, pos_lambda: 0.6982, neg_lambda: 0.0599, best_loss: 0.2442
# Epoch 1925/10000, Loss: 0.2442, pos_d: 0.7144, neg_d(sampled): 5.2346, pos_lambda: 0.6992, neg_lambda: 0.0598, best_loss: 0.2439
# Epoch 1950/10000, Loss: 0.2438, pos_d: 0.7153, neg_d(sampled): 5.2508, pos_lambda: 0.7003, neg_lambda: 0.0594, best_loss: 0.2437
# Epoch 1975/10000, Loss: 0.2438, pos_d: 0.7162, neg_d(sampled): 5.2699, pos_lambda: 0.7013, neg_lambda: 0.0595, best_loss: 0.2436
# Epoch 2000/10000, Loss: 0.2437, pos_d: 0.7172, neg_d(sampled): 5.2922, pos_lambda: 0.7023, neg_lambda: 0.0594, best_loss: 0.2432
# Epoch 2025/10000, Loss: 0.2434, pos_d: 0.7182, neg_d(sampled): 5.3072, pos_lambda: 0.7031, neg_lambda: 0.0591, best_loss: 0.2431
# Epoch 2050/10000, Loss: 0.2433, pos_d: 0.7191, neg_d(sampled): 5.3198, pos_lambda: 0.7041, neg_lambda: 0.0590, best_loss: 0.2431
# Epoch 2075/10000, Loss: 0.2429, pos_d: 0.7201, neg_d(sampled): 5.3417, pos_lambda: 0.7049, neg_lambda: 0.0585, best_loss: 0.2429
# Epoch 2100/10000, Loss: 0.2428, pos_d: 0.7212, neg_d(sampled): 5.3560, pos_lambda: 0.7060, neg_lambda: 0.0585, best_loss: 0.2426
# Epoch 2125/10000, Loss: 0.2425, pos_d: 0.7222, neg_d(sampled): 5.3778, pos_lambda: 0.7068, neg_lambda: 0.0581, best_loss: 0.2425
# Epoch 2150/10000, Loss: 0.2425, pos_d: 0.7233, neg_d(sampled): 5.3866, pos_lambda: 0.7076, neg_lambda: 0.0581, best_loss: 0.2423
# Epoch 2175/10000, Loss: 0.2423, pos_d: 0.7244, neg_d(sampled): 5.4035, pos_lambda: 0.7086, neg_lambda: 0.0579, best_loss: 0.2422
# Epoch 2200/10000, Loss: 0.2422, pos_d: 0.7255, neg_d(sampled): 5.4221, pos_lambda: 0.7095, neg_lambda: 0.0578, best_loss: 0.2420
# Epoch 2225/10000, Loss: 0.2419, pos_d: 0.7266, neg_d(sampled): 5.4410, pos_lambda: 0.7102, neg_lambda: 0.0575, best_loss: 0.2418
# Epoch 2250/10000, Loss: 0.2421, pos_d: 0.7278, neg_d(sampled): 5.4496, pos_lambda: 0.7109, neg_lambda: 0.0577, best_loss: 0.2418
# Epoch 2275/10000, Loss: 0.2420, pos_d: 0.7289, neg_d(sampled): 5.4672, pos_lambda: 0.7117, neg_lambda: 0.0576, best_loss: 0.2416
# Epoch 2300/10000, Loss: 0.2416, pos_d: 0.7301, neg_d(sampled): 5.4865, pos_lambda: 0.7125, neg_lambda: 0.0571, best_loss: 0.2414
# Epoch 2325/10000, Loss: 0.2414, pos_d: 0.7312, neg_d(sampled): 5.5051, pos_lambda: 0.7134, neg_lambda: 0.0570, best_loss: 0.2412
# Epoch 2350/10000, Loss: 0.2413, pos_d: 0.7324, neg_d(sampled): 5.5161, pos_lambda: 0.7142, neg_lambda: 0.0568, best_loss: 0.2411
# Epoch 2375/10000, Loss: 0.2413, pos_d: 0.7336, neg_d(sampled): 5.5324, pos_lambda: 0.7151, neg_lambda: 0.0568, best_loss: 0.2409
# Epoch 2400/10000, Loss: 0.2410, pos_d: 0.7348, neg_d(sampled): 5.5487, pos_lambda: 0.7156, neg_lambda: 0.0564, best_loss: 0.2408
# Epoch 2425/10000, Loss: 0.2409, pos_d: 0.7360, neg_d(sampled): 5.5669, pos_lambda: 0.7164, neg_lambda: 0.0564, best_loss: 0.2407
# Epoch 2450/10000, Loss: 0.2409, pos_d: 0.7372, neg_d(sampled): 5.5772, pos_lambda: 0.7171, neg_lambda: 0.0564, best_loss: 0.2405
# Epoch 2475/10000, Loss: 0.2404, pos_d: 0.7384, neg_d(sampled): 5.6017, pos_lambda: 0.7176, neg_lambda: 0.0558, best_loss: 0.2404
# Epoch 2500/10000, Loss: 0.2408, pos_d: 0.7397, neg_d(sampled): 5.6103, pos_lambda: 0.7183, neg_lambda: 0.0563, best_loss: 0.2404
# Epoch 2525/10000, Loss: 0.2404, pos_d: 0.7409, neg_d(sampled): 5.6230, pos_lambda: 0.7191, neg_lambda: 0.0558, best_loss: 0.2402
# Epoch 2550/10000, Loss: 0.2404, pos_d: 0.7422, neg_d(sampled): 5.6413, pos_lambda: 0.7198, neg_lambda: 0.0558, best_loss: 0.2401
# Epoch 2575/10000, Loss: 0.2401, pos_d: 0.7434, neg_d(sampled): 5.6592, pos_lambda: 0.7204, neg_lambda: 0.0555, best_loss: 0.2400
# Epoch 2600/10000, Loss: 0.2400, pos_d: 0.7447, neg_d(sampled): 5.6728, pos_lambda: 0.7211, neg_lambda: 0.0553, best_loss: 0.2400
# Epoch 2625/10000, Loss: 0.2400, pos_d: 0.7460, neg_d(sampled): 5.6855, pos_lambda: 0.7218, neg_lambda: 0.0553, best_loss: 0.2398
# Epoch 2650/10000, Loss: 0.2400, pos_d: 0.7473, neg_d(sampled): 5.6983, pos_lambda: 0.7222, neg_lambda: 0.0553, best_loss: 0.2397
# Epoch 2675/10000, Loss: 0.2397, pos_d: 0.7486, neg_d(sampled): 5.7168, pos_lambda: 0.7229, neg_lambda: 0.0549, best_loss: 0.2395
# Epoch 2700/10000, Loss: 0.2395, pos_d: 0.7499, neg_d(sampled): 5.7278, pos_lambda: 0.7236, neg_lambda: 0.0548, best_loss: 0.2395
# Epoch 2725/10000, Loss: 0.2397, pos_d: 0.7511, neg_d(sampled): 5.7392, pos_lambda: 0.7242, neg_lambda: 0.0550, best_loss: 0.2395
# Epoch 2750/10000, Loss: 0.2393, pos_d: 0.7524, neg_d(sampled): 5.7590, pos_lambda: 0.7247, neg_lambda: 0.0545, best_loss: 0.2392
# Epoch 2775/10000, Loss: 0.2394, pos_d: 0.7536, neg_d(sampled): 5.7721, pos_lambda: 0.7254, neg_lambda: 0.0546, best_loss: 0.2391
# Epoch 2800/10000, Loss: 0.2389, pos_d: 0.7549, neg_d(sampled): 5.7843, pos_lambda: 0.7259, neg_lambda: 0.0540, best_loss: 0.2389
# Epoch 2825/10000, Loss: 0.2392, pos_d: 0.7562, neg_d(sampled): 5.7948, pos_lambda: 0.7265, neg_lambda: 0.0544, best_loss: 0.2389
# Epoch 2850/10000, Loss: 0.2391, pos_d: 0.7575, neg_d(sampled): 5.8117, pos_lambda: 0.7270, neg_lambda: 0.0543, best_loss: 0.2389
# Epoch 2875/10000, Loss: 0.2389, pos_d: 0.7588, neg_d(sampled): 5.8262, pos_lambda: 0.7275, neg_lambda: 0.0540, best_loss: 0.2387
# Epoch 2900/10000, Loss: 0.2390, pos_d: 0.7600, neg_d(sampled): 5.8372, pos_lambda: 0.7282, neg_lambda: 0.0542, best_loss: 0.2387
# Epoch 2925/10000, Loss: 0.2390, pos_d: 0.7613, neg_d(sampled): 5.8457, pos_lambda: 0.7286, neg_lambda: 0.0541, best_loss: 0.2387
# Epoch 2950/10000, Loss: 0.2385, pos_d: 0.7626, neg_d(sampled): 5.8649, pos_lambda: 0.7292, neg_lambda: 0.0535, best_loss: 0.2385
# Epoch 2975/10000, Loss: 0.2387, pos_d: 0.7639, neg_d(sampled): 5.8734, pos_lambda: 0.7296, neg_lambda: 0.0537, best_loss: 0.2385
# Epoch 3000/10000, Loss: 0.2387, pos_d: 0.7652, neg_d(sampled): 5.8855, pos_lambda: 0.7302, neg_lambda: 0.0537, best_loss: 0.2384
# Epoch 3025/10000, Loss: 0.2385, pos_d: 0.7664, neg_d(sampled): 5.9019, pos_lambda: 0.7306, neg_lambda: 0.0535, best_loss: 0.2384
# Epoch 3050/10000, Loss: 0.2384, pos_d: 0.7677, neg_d(sampled): 5.9162, pos_lambda: 0.7312, neg_lambda: 0.0534, best_loss: 0.2383
# Epoch 3075/10000, Loss: 0.2385, pos_d: 0.7690, neg_d(sampled): 5.9266, pos_lambda: 0.7317, neg_lambda: 0.0535, best_loss: 0.2382
# Epoch 3100/10000, Loss: 0.2386, pos_d: 0.7702, neg_d(sampled): 5.9388, pos_lambda: 0.7321, neg_lambda: 0.0536, best_loss: 0.2382
# Epoch 3125/10000, Loss: 0.2382, pos_d: 0.7715, neg_d(sampled): 5.9500, pos_lambda: 0.7324, neg_lambda: 0.0531, best_loss: 0.2382
# Epoch 3150/10000, Loss: 0.2382, pos_d: 0.7728, neg_d(sampled): 5.9644, pos_lambda: 0.7329, neg_lambda: 0.0531, best_loss: 0.2380
# Epoch 3175/10000, Loss: 0.2381, pos_d: 0.7740, neg_d(sampled): 5.9813, pos_lambda: 0.7336, neg_lambda: 0.0529, best_loss: 0.2380
# Epoch 3200/10000, Loss: 0.2380, pos_d: 0.7753, neg_d(sampled): 5.9928, pos_lambda: 0.7341, neg_lambda: 0.0528, best_loss: 0.2379
# Epoch 3225/10000, Loss: 0.2380, pos_d: 0.7765, neg_d(sampled): 6.0056, pos_lambda: 0.7344, neg_lambda: 0.0529, best_loss: 0.2378
# Epoch 3250/10000, Loss: 0.2380, pos_d: 0.7778, neg_d(sampled): 6.0098, pos_lambda: 0.7348, neg_lambda: 0.0528, best_loss: 0.2377
# Epoch 3275/10000, Loss: 0.2379, pos_d: 0.7790, neg_d(sampled): 6.0271, pos_lambda: 0.7352, neg_lambda: 0.0527, best_loss: 0.2376
# Epoch 3300/10000, Loss: 0.2378, pos_d: 0.7802, neg_d(sampled): 6.0367, pos_lambda: 0.7358, neg_lambda: 0.0525, best_loss: 0.2376
# Epoch 3325/10000, Loss: 0.2378, pos_d: 0.7814, neg_d(sampled): 6.0504, pos_lambda: 0.7360, neg_lambda: 0.0525, best_loss: 0.2375
# Epoch 3350/10000, Loss: 0.2377, pos_d: 0.7826, neg_d(sampled): 6.0615, pos_lambda: 0.7366, neg_lambda: 0.0524, best_loss: 0.2374
# Epoch 3375/10000, Loss: 0.2378, pos_d: 0.7838, neg_d(sampled): 6.0720, pos_lambda: 0.7370, neg_lambda: 0.0526, best_loss: 0.2374
# Epoch 3400/10000, Loss: 0.2376, pos_d: 0.7850, neg_d(sampled): 6.0803, pos_lambda: 0.7374, neg_lambda: 0.0523, best_loss: 0.2373
# Epoch 3425/10000, Loss: 0.2376, pos_d: 0.7862, neg_d(sampled): 6.0915, pos_lambda: 0.7378, neg_lambda: 0.0524, best_loss: 0.2373
# Epoch 3450/10000, Loss: 0.2376, pos_d: 0.7874, neg_d(sampled): 6.1020, pos_lambda: 0.7382, neg_lambda: 0.0523, best_loss: 0.2371
# Epoch 3475/10000, Loss: 0.2373, pos_d: 0.7886, neg_d(sampled): 6.1223, pos_lambda: 0.7385, neg_lambda: 0.0519, best_loss: 0.2371
# Epoch 3500/10000, Loss: 0.2374, pos_d: 0.7898, neg_d(sampled): 6.1281, pos_lambda: 0.7390, neg_lambda: 0.0520, best_loss: 0.2371
# Epoch 3525/10000, Loss: 0.2373, pos_d: 0.7910, neg_d(sampled): 6.1369, pos_lambda: 0.7395, neg_lambda: 0.0519, best_loss: 0.2371
# Epoch 3550/10000, Loss: 0.2371, pos_d: 0.7922, neg_d(sampled): 6.1485, pos_lambda: 0.7398, neg_lambda: 0.0516, best_loss: 0.2370
# Epoch 3575/10000, Loss: 0.2373, pos_d: 0.7934, neg_d(sampled): 6.1564, pos_lambda: 0.7400, neg_lambda: 0.0519, best_loss: 0.2370
# Epoch 3600/10000, Loss: 0.2372, pos_d: 0.7945, neg_d(sampled): 6.1704, pos_lambda: 0.7404, neg_lambda: 0.0518, best_loss: 0.2369
# Epoch 3625/10000, Loss: 0.2371, pos_d: 0.7956, neg_d(sampled): 6.1861, pos_lambda: 0.7408, neg_lambda: 0.0516, best_loss: 0.2369
# Epoch 3650/10000, Loss: 0.2370, pos_d: 0.7968, neg_d(sampled): 6.1931, pos_lambda: 0.7412, neg_lambda: 0.0515, best_loss: 0.2369
# Epoch 3675/10000, Loss: 0.2369, pos_d: 0.7979, neg_d(sampled): 6.2058, pos_lambda: 0.7415, neg_lambda: 0.0513, best_loss: 0.2368
# Epoch 3700/10000, Loss: 0.2371, pos_d: 0.7990, neg_d(sampled): 6.2120, pos_lambda: 0.7418, neg_lambda: 0.0516, best_loss: 0.2366
# Epoch 3725/10000, Loss: 0.2369, pos_d: 0.8002, neg_d(sampled): 6.2250, pos_lambda: 0.7421, neg_lambda: 0.0514, best_loss: 0.2366
# Epoch 3750/10000, Loss: 0.2368, pos_d: 0.8013, neg_d(sampled): 6.2385, pos_lambda: 0.7425, neg_lambda: 0.0512, best_loss: 0.2366
# Epoch 3775/10000, Loss: 0.2367, pos_d: 0.8025, neg_d(sampled): 6.2416, pos_lambda: 0.7428, neg_lambda: 0.0511, best_loss: 0.2366
# Epoch 3800/10000, Loss: 0.2365, pos_d: 0.8036, neg_d(sampled): 6.2607, pos_lambda: 0.7431, neg_lambda: 0.0508, best_loss: 0.2365
# Epoch 3825/10000, Loss: 0.2368, pos_d: 0.8047, neg_d(sampled): 6.2646, pos_lambda: 0.7436, neg_lambda: 0.0512, best_loss: 0.2365
# Epoch 3850/10000, Loss: 0.2364, pos_d: 0.8057, neg_d(sampled): 6.2758, pos_lambda: 0.7437, neg_lambda: 0.0507, best_loss: 0.2364
# Epoch 3875/10000, Loss: 0.2367, pos_d: 0.8068, neg_d(sampled): 6.2886, pos_lambda: 0.7444, neg_lambda: 0.0510, best_loss: 0.2364
# Epoch 3900/10000, Loss: 0.2364, pos_d: 0.8079, neg_d(sampled): 6.2972, pos_lambda: 0.7446, neg_lambda: 0.0506, best_loss: 0.2363
# Epoch 3925/10000, Loss: 0.2364, pos_d: 0.8090, neg_d(sampled): 6.3065, pos_lambda: 0.7447, neg_lambda: 0.0506, best_loss: 0.2363
# Epoch 3950/10000, Loss: 0.2367, pos_d: 0.8101, neg_d(sampled): 6.3147, pos_lambda: 0.7451, neg_lambda: 0.0510, best_loss: 0.2363
# Epoch 3975/10000, Loss: 0.2363, pos_d: 0.8111, neg_d(sampled): 6.3214, pos_lambda: 0.7454, neg_lambda: 0.0506, best_loss: 0.2362
# Epoch 4000/10000, Loss: 0.2364, pos_d: 0.8121, neg_d(sampled): 6.3341, pos_lambda: 0.7458, neg_lambda: 0.0506, best_loss: 0.2362
# Epoch 4025/10000, Loss: 0.2363, pos_d: 0.8132, neg_d(sampled): 6.3414, pos_lambda: 0.7461, neg_lambda: 0.0505, best_loss: 0.2362
# Epoch 4050/10000, Loss: 0.2361, pos_d: 0.8142, neg_d(sampled): 6.3537, pos_lambda: 0.7461, neg_lambda: 0.0502, best_loss: 0.2361
# Epoch 4075/10000, Loss: 0.2362, pos_d: 0.8153, neg_d(sampled): 6.3582, pos_lambda: 0.7465, neg_lambda: 0.0503, best_loss: 0.2361
# Epoch 4100/10000, Loss: 0.2362, pos_d: 0.8162, neg_d(sampled): 6.3653, pos_lambda: 0.7468, neg_lambda: 0.0503, best_loss: 0.2360
# Epoch 4125/10000, Loss: 0.2364, pos_d: 0.8172, neg_d(sampled): 6.3813, pos_lambda: 0.7471, neg_lambda: 0.0505, best_loss: 0.2360
# Epoch 4150/10000, Loss: 0.2362, pos_d: 0.8182, neg_d(sampled): 6.3906, pos_lambda: 0.7476, neg_lambda: 0.0503, best_loss: 0.2359
# Epoch 4175/10000, Loss: 0.2359, pos_d: 0.8193, neg_d(sampled): 6.3968, pos_lambda: 0.7477, neg_lambda: 0.0500, best_loss: 0.2358
# Epoch 4200/10000, Loss: 0.2363, pos_d: 0.8203, neg_d(sampled): 6.3998, pos_lambda: 0.7480, neg_lambda: 0.0503, best_loss: 0.2358
# Epoch 4225/10000, Loss: 0.2361, pos_d: 0.8212, neg_d(sampled): 6.4087, pos_lambda: 0.7483, neg_lambda: 0.0502, best_loss: 0.2358
# Epoch 4250/10000, Loss: 0.2360, pos_d: 0.8222, neg_d(sampled): 6.4203, pos_lambda: 0.7486, neg_lambda: 0.0500, best_loss: 0.2357
# Epoch 4275/10000, Loss: 0.2358, pos_d: 0.8232, neg_d(sampled): 6.4291, pos_lambda: 0.7489, neg_lambda: 0.0498, best_loss: 0.2357
# Epoch 4300/10000, Loss: 0.2360, pos_d: 0.8242, neg_d(sampled): 6.4393, pos_lambda: 0.7493, neg_lambda: 0.0500, best_loss: 0.2356
# Epoch 4325/10000, Loss: 0.2360, pos_d: 0.8251, neg_d(sampled): 6.4459, pos_lambda: 0.7495, neg_lambda: 0.0500, best_loss: 0.2356
# Epoch 4350/10000, Loss: 0.2359, pos_d: 0.8261, neg_d(sampled): 6.4561, pos_lambda: 0.7497, neg_lambda: 0.0498, best_loss: 0.2356
# Epoch 4375/10000, Loss: 0.2359, pos_d: 0.8270, neg_d(sampled): 6.4606, pos_lambda: 0.7499, neg_lambda: 0.0498, best_loss: 0.2356
# Epoch 4400/10000, Loss: 0.2359, pos_d: 0.8279, neg_d(sampled): 6.4727, pos_lambda: 0.7502, neg_lambda: 0.0498, best_loss: 0.2356
# Epoch 4425/10000, Loss: 0.2359, pos_d: 0.8288, neg_d(sampled): 6.4784, pos_lambda: 0.7503, neg_lambda: 0.0498, best_loss: 0.2356
# Epoch 4450/10000, Loss: 0.2360, pos_d: 0.8297, neg_d(sampled): 6.4847, pos_lambda: 0.7505, neg_lambda: 0.0499, best_loss: 0.2356
# Epoch 4475/10000, Loss: 0.2358, pos_d: 0.8306, neg_d(sampled): 6.4969, pos_lambda: 0.7507, neg_lambda: 0.0497, best_loss: 0.2354
# Epoch 4500/10000, Loss: 0.2357, pos_d: 0.8315, neg_d(sampled): 6.5096, pos_lambda: 0.7511, neg_lambda: 0.0495, best_loss: 0.2354
# Epoch 4525/10000, Loss: 0.2358, pos_d: 0.8324, neg_d(sampled): 6.5073, pos_lambda: 0.7513, neg_lambda: 0.0497, best_loss: 0.2354
# Epoch 4550/10000, Loss: 0.2357, pos_d: 0.8332, neg_d(sampled): 6.5166, pos_lambda: 0.7516, neg_lambda: 0.0495, best_loss: 0.2353
# Epoch 4575/10000, Loss: 0.2357, pos_d: 0.8340, neg_d(sampled): 6.5249, pos_lambda: 0.7517, neg_lambda: 0.0495, best_loss: 0.2353
# Epoch 4600/10000, Loss: 0.2357, pos_d: 0.8348, neg_d(sampled): 6.5334, pos_lambda: 0.7520, neg_lambda: 0.0495, best_loss: 0.2353
# Epoch 4625/10000, Loss: 0.2355, pos_d: 0.8357, neg_d(sampled): 6.5453, pos_lambda: 0.7523, neg_lambda: 0.0492, best_loss: 0.2353
# Epoch 4650/10000, Loss: 0.2356, pos_d: 0.8365, neg_d(sampled): 6.5506, pos_lambda: 0.7524, neg_lambda: 0.0494, best_loss: 0.2353
# Epoch 4675/10000, Loss: 0.2357, pos_d: 0.8373, neg_d(sampled): 6.5575, pos_lambda: 0.7527, neg_lambda: 0.0494, best_loss: 0.2353
# Epoch 4700/10000, Loss: 0.2355, pos_d: 0.8381, neg_d(sampled): 6.5644, pos_lambda: 0.7530, neg_lambda: 0.0493, best_loss: 0.2352
# Epoch 4725/10000, Loss: 0.2357, pos_d: 0.8389, neg_d(sampled): 6.5738, pos_lambda: 0.7532, neg_lambda: 0.0494, best_loss: 0.2352
# Epoch 4750/10000, Loss: 0.2354, pos_d: 0.8397, neg_d(sampled): 6.5798, pos_lambda: 0.7534, neg_lambda: 0.0491, best_loss: 0.2350
# Epoch 4775/10000, Loss: 0.2355, pos_d: 0.8405, neg_d(sampled): 6.5844, pos_lambda: 0.7539, neg_lambda: 0.0492, best_loss: 0.2350
# Epoch 4800/10000, Loss: 0.2353, pos_d: 0.8413, neg_d(sampled): 6.5976, pos_lambda: 0.7538, neg_lambda: 0.0490, best_loss: 0.2350
# Epoch 4825/10000, Loss: 0.2353, pos_d: 0.8421, neg_d(sampled): 6.6053, pos_lambda: 0.7542, neg_lambda: 0.0489, best_loss: 0.2350
# Epoch 4850/10000, Loss: 0.2352, pos_d: 0.8428, neg_d(sampled): 6.6113, pos_lambda: 0.7542, neg_lambda: 0.0489, best_loss: 0.2350
# Epoch 4875/10000, Loss: 0.2353, pos_d: 0.8435, neg_d(sampled): 6.6195, pos_lambda: 0.7547, neg_lambda: 0.0490, best_loss: 0.2350
# Epoch 4900/10000, Loss: 0.2352, pos_d: 0.8443, neg_d(sampled): 6.6242, pos_lambda: 0.7547, neg_lambda: 0.0488, best_loss: 0.2350
# Epoch 4925/10000, Loss: 0.2354, pos_d: 0.8450, neg_d(sampled): 6.6279, pos_lambda: 0.7549, neg_lambda: 0.0490, best_loss: 0.2350
# Epoch 4950/10000, Loss: 0.2353, pos_d: 0.8457, neg_d(sampled): 6.6382, pos_lambda: 0.7551, neg_lambda: 0.0488, best_loss: 0.2350
# Epoch 4975/10000, Loss: 0.2354, pos_d: 0.8464, neg_d(sampled): 6.6433, pos_lambda: 0.7554, neg_lambda: 0.0491, best_loss: 0.2349
# Epoch 5000/10000, Loss: 0.2350, pos_d: 0.8472, neg_d(sampled): 6.6503, pos_lambda: 0.7557, neg_lambda: 0.0486, best_loss: 0.2349
# Epoch 5025/10000, Loss: 0.2353, pos_d: 0.8479, neg_d(sampled): 6.6577, pos_lambda: 0.7558, neg_lambda: 0.0489, best_loss: 0.2349
# Epoch 5050/10000, Loss: 0.2353, pos_d: 0.8486, neg_d(sampled): 6.6623, pos_lambda: 0.7562, neg_lambda: 0.0488, best_loss: 0.2348
# Epoch 5075/10000, Loss: 0.2352, pos_d: 0.8493, neg_d(sampled): 6.6689, pos_lambda: 0.7559, neg_lambda: 0.0487, best_loss: 0.2348
# Epoch 5100/10000, Loss: 0.2353, pos_d: 0.8500, neg_d(sampled): 6.6734, pos_lambda: 0.7562, neg_lambda: 0.0488, best_loss: 0.2346
# Epoch 5125/10000, Loss: 0.2352, pos_d: 0.8507, neg_d(sampled): 6.6779, pos_lambda: 0.7565, neg_lambda: 0.0487, best_loss: 0.2346
# Epoch 5150/10000, Loss: 0.2350, pos_d: 0.8514, neg_d(sampled): 6.6897, pos_lambda: 0.7567, neg_lambda: 0.0484, best_loss: 0.2346
# Epoch 5175/10000, Loss: 0.2353, pos_d: 0.8521, neg_d(sampled): 6.6922, pos_lambda: 0.7571, neg_lambda: 0.0488, best_loss: 0.2346
# Epoch 5200/10000, Loss: 0.2352, pos_d: 0.8527, neg_d(sampled): 6.6987, pos_lambda: 0.7571, neg_lambda: 0.0486, best_loss: 0.2346
# Epoch 5225/10000, Loss: 0.2350, pos_d: 0.8534, neg_d(sampled): 6.7070, pos_lambda: 0.7574, neg_lambda: 0.0485, best_loss: 0.2346
# Epoch 5250/10000, Loss: 0.2349, pos_d: 0.8541, neg_d(sampled): 6.7210, pos_lambda: 0.7575, neg_lambda: 0.0483, best_loss: 0.2346
# Epoch 5275/10000, Loss: 0.2347, pos_d: 0.8547, neg_d(sampled): 6.7257, pos_lambda: 0.7576, neg_lambda: 0.0481, best_loss: 0.2346
# Epoch 5300/10000, Loss: 0.2348, pos_d: 0.8554, neg_d(sampled): 6.7260, pos_lambda: 0.7578, neg_lambda: 0.0482, best_loss: 0.2346
# Epoch 5325/10000, Loss: 0.2348, pos_d: 0.8560, neg_d(sampled): 6.7395, pos_lambda: 0.7580, neg_lambda: 0.0482, best_loss: 0.2346
# Epoch 5350/10000, Loss: 0.2351, pos_d: 0.8566, neg_d(sampled): 6.7360, pos_lambda: 0.7582, neg_lambda: 0.0485, best_loss: 0.2346
# Epoch 5375/10000, Loss: 0.2351, pos_d: 0.8572, neg_d(sampled): 6.7413, pos_lambda: 0.7584, neg_lambda: 0.0485, best_loss: 0.2346
# Epoch 5400/10000, Loss: 0.2349, pos_d: 0.8579, neg_d(sampled): 6.7520, pos_lambda: 0.7586, neg_lambda: 0.0483, best_loss: 0.2345
# Epoch 5425/10000, Loss: 0.2348, pos_d: 0.8585, neg_d(sampled): 6.7568, pos_lambda: 0.7587, neg_lambda: 0.0481, best_loss: 0.2345
# Epoch 5450/10000, Loss: 0.2349, pos_d: 0.8592, neg_d(sampled): 6.7617, pos_lambda: 0.7588, neg_lambda: 0.0482, best_loss: 0.2345
# Epoch 5475/10000, Loss: 0.2349, pos_d: 0.8598, neg_d(sampled): 6.7674, pos_lambda: 0.7589, neg_lambda: 0.0482, best_loss: 0.2345
# Epoch 5500/10000, Loss: 0.2348, pos_d: 0.8604, neg_d(sampled): 6.7783, pos_lambda: 0.7593, neg_lambda: 0.0481, best_loss: 0.2345
# Epoch 5525/10000, Loss: 0.2348, pos_d: 0.8610, neg_d(sampled): 6.7799, pos_lambda: 0.7593, neg_lambda: 0.0481, best_loss: 0.2345
# Epoch 5550/10000, Loss: 0.2348, pos_d: 0.8616, neg_d(sampled): 6.7867, pos_lambda: 0.7595, neg_lambda: 0.0481, best_loss: 0.2345
# Epoch 5575/10000, Loss: 0.2346, pos_d: 0.8623, neg_d(sampled): 6.7968, pos_lambda: 0.7596, neg_lambda: 0.0478, best_loss: 0.2344
# Epoch 5600/10000, Loss: 0.2347, pos_d: 0.8628, neg_d(sampled): 6.8039, pos_lambda: 0.7598, neg_lambda: 0.0479, best_loss: 0.2344
# Epoch 5625/10000, Loss: 0.2345, pos_d: 0.8634, neg_d(sampled): 6.8097, pos_lambda: 0.7599, neg_lambda: 0.0477, best_loss: 0.2344
# Epoch 5650/10000, Loss: 0.2346, pos_d: 0.8639, neg_d(sampled): 6.8062, pos_lambda: 0.7603, neg_lambda: 0.0478, best_loss: 0.2344
# Epoch 5675/10000, Loss: 0.2343, pos_d: 0.8645, neg_d(sampled): 6.8200, pos_lambda: 0.7604, neg_lambda: 0.0475, best_loss: 0.2343
# Epoch 5700/10000, Loss: 0.2346, pos_d: 0.8650, neg_d(sampled): 6.8145, pos_lambda: 0.7606, neg_lambda: 0.0477, best_loss: 0.2343
# Epoch 5725/10000, Loss: 0.2347, pos_d: 0.8655, neg_d(sampled): 6.8210, pos_lambda: 0.7606, neg_lambda: 0.0479, best_loss: 0.2343
# Epoch 5750/10000, Loss: 0.2343, pos_d: 0.8661, neg_d(sampled): 6.8348, pos_lambda: 0.7608, neg_lambda: 0.0474, best_loss: 0.2343
# Epoch 5775/10000, Loss: 0.2344, pos_d: 0.8666, neg_d(sampled): 6.8405, pos_lambda: 0.7609, neg_lambda: 0.0475, best_loss: 0.2342
# Epoch 5800/10000, Loss: 0.2342, pos_d: 0.8672, neg_d(sampled): 6.8455, pos_lambda: 0.7610, neg_lambda: 0.0473, best_loss: 0.2342
# Epoch 5825/10000, Loss: 0.2344, pos_d: 0.8678, neg_d(sampled): 6.8480, pos_lambda: 0.7612, neg_lambda: 0.0475, best_loss: 0.2342
# Epoch 5850/10000, Loss: 0.2345, pos_d: 0.8683, neg_d(sampled): 6.8523, pos_lambda: 0.7613, neg_lambda: 0.0476, best_loss: 0.2342
# Epoch 5875/10000, Loss: 0.2346, pos_d: 0.8688, neg_d(sampled): 6.8518, pos_lambda: 0.7614, neg_lambda: 0.0478, best_loss: 0.2342
# Epoch 5900/10000, Loss: 0.2343, pos_d: 0.8693, neg_d(sampled): 6.8638, pos_lambda: 0.7616, neg_lambda: 0.0473, best_loss: 0.2342
# Epoch 5925/10000, Loss: 0.2346, pos_d: 0.8698, neg_d(sampled): 6.8626, pos_lambda: 0.7617, neg_lambda: 0.0477, best_loss: 0.2342
# Epoch 5950/10000, Loss: 0.2346, pos_d: 0.8703, neg_d(sampled): 6.8613, pos_lambda: 0.7618, neg_lambda: 0.0477, best_loss: 0.2342
# Epoch 5975/10000, Loss: 0.2346, pos_d: 0.8708, neg_d(sampled): 6.8717, pos_lambda: 0.7619, neg_lambda: 0.0476, best_loss: 0.2342
# Epoch 6000/10000, Loss: 0.2346, pos_d: 0.8713, neg_d(sampled): 6.8768, pos_lambda: 0.7621, neg_lambda: 0.0477, best_loss: 0.2342
# Epoch 6025/10000, Loss: 0.2344, pos_d: 0.8718, neg_d(sampled): 6.8913, pos_lambda: 0.7624, neg_lambda: 0.0474, best_loss: 0.2341
# Epoch 6050/10000, Loss: 0.2343, pos_d: 0.8723, neg_d(sampled): 6.8904, pos_lambda: 0.7626, neg_lambda: 0.0473, best_loss: 0.2341
# Epoch 6075/10000, Loss: 0.2344, pos_d: 0.8728, neg_d(sampled): 6.8934, pos_lambda: 0.7624, neg_lambda: 0.0473, best_loss: 0.2341
# Epoch 6100/10000, Loss: 0.2346, pos_d: 0.8733, neg_d(sampled): 6.8994, pos_lambda: 0.7627, neg_lambda: 0.0476, best_loss: 0.2340
# Epoch 6125/10000, Loss: 0.2344, pos_d: 0.8738, neg_d(sampled): 6.8987, pos_lambda: 0.7627, neg_lambda: 0.0474, best_loss: 0.2340
# Epoch 6150/10000, Loss: 0.2345, pos_d: 0.8743, neg_d(sampled): 6.9060, pos_lambda: 0.7629, neg_lambda: 0.0475, best_loss: 0.2340
# Epoch 6175/10000, Loss: 0.2343, pos_d: 0.8747, neg_d(sampled): 6.9133, pos_lambda: 0.7632, neg_lambda: 0.0472, best_loss: 0.2340
# Epoch 6200/10000, Loss: 0.2342, pos_d: 0.8753, neg_d(sampled): 6.9221, pos_lambda: 0.7633, neg_lambda: 0.0471, best_loss: 0.2340
# Epoch 6225/10000, Loss: 0.2341, pos_d: 0.8758, neg_d(sampled): 6.9208, pos_lambda: 0.7633, neg_lambda: 0.0470, best_loss: 0.2340
# Epoch 6250/10000, Loss: 0.2344, pos_d: 0.8761, neg_d(sampled): 6.9264, pos_lambda: 0.7635, neg_lambda: 0.0473, best_loss: 0.2340
# Epoch 6275/10000, Loss: 0.2341, pos_d: 0.8766, neg_d(sampled): 6.9303, pos_lambda: 0.7636, neg_lambda: 0.0470, best_loss: 0.2339
# Epoch 6300/10000, Loss: 0.2344, pos_d: 0.8771, neg_d(sampled): 6.9336, pos_lambda: 0.7636, neg_lambda: 0.0473, best_loss: 0.2339
# Epoch 6325/10000, Loss: 0.2344, pos_d: 0.8776, neg_d(sampled): 6.9365, pos_lambda: 0.7638, neg_lambda: 0.0474, best_loss: 0.2339
# Epoch 6350/10000, Loss: 0.2343, pos_d: 0.8780, neg_d(sampled): 6.9480, pos_lambda: 0.7639, neg_lambda: 0.0471, best_loss: 0.2339
# Epoch 6375/10000, Loss: 0.2342, pos_d: 0.8784, neg_d(sampled): 6.9529, pos_lambda: 0.7639, neg_lambda: 0.0471, best_loss: 0.2339
# Epoch 6400/10000, Loss: 0.2342, pos_d: 0.8789, neg_d(sampled): 6.9562, pos_lambda: 0.7641, neg_lambda: 0.0471, best_loss: 0.2339
# Epoch 6425/10000, Loss: 0.2342, pos_d: 0.8793, neg_d(sampled): 6.9597, pos_lambda: 0.7641, neg_lambda: 0.0470, best_loss: 0.2339
# Epoch 6450/10000, Loss: 0.2343, pos_d: 0.8797, neg_d(sampled): 6.9605, pos_lambda: 0.7644, neg_lambda: 0.0471, best_loss: 0.2338
# Epoch 6475/10000, Loss: 0.2342, pos_d: 0.8801, neg_d(sampled): 6.9608, pos_lambda: 0.7644, neg_lambda: 0.0470, best_loss: 0.2338
# Epoch 6500/10000, Loss: 0.2341, pos_d: 0.8805, neg_d(sampled): 6.9680, pos_lambda: 0.7645, neg_lambda: 0.0469, best_loss: 0.2338
# Epoch 6525/10000, Loss: 0.2342, pos_d: 0.8809, neg_d(sampled): 6.9735, pos_lambda: 0.7646, neg_lambda: 0.0470, best_loss: 0.2338
# Epoch 6550/10000, Loss: 0.2341, pos_d: 0.8813, neg_d(sampled): 6.9760, pos_lambda: 0.7648, neg_lambda: 0.0469, best_loss: 0.2338
# Epoch 6575/10000, Loss: 0.2344, pos_d: 0.8817, neg_d(sampled): 6.9790, pos_lambda: 0.7649, neg_lambda: 0.0472, best_loss: 0.2338
# Epoch 6600/10000, Loss: 0.2340, pos_d: 0.8821, neg_d(sampled): 6.9867, pos_lambda: 0.7650, neg_lambda: 0.0467, best_loss: 0.2338
# Epoch 6625/10000, Loss: 0.2343, pos_d: 0.8825, neg_d(sampled): 6.9854, pos_lambda: 0.7650, neg_lambda: 0.0472, best_loss: 0.2338
# Epoch 6650/10000, Loss: 0.2340, pos_d: 0.8829, neg_d(sampled): 6.9919, pos_lambda: 0.7651, neg_lambda: 0.0468, best_loss: 0.2338
# Epoch 6675/10000, Loss: 0.2343, pos_d: 0.8833, neg_d(sampled): 7.0016, pos_lambda: 0.7652, neg_lambda: 0.0470, best_loss: 0.2338
# Epoch 6700/10000, Loss: 0.2340, pos_d: 0.8837, neg_d(sampled): 6.9995, pos_lambda: 0.7655, neg_lambda: 0.0467, best_loss: 0.2337
# Epoch 6725/10000, Loss: 0.2343, pos_d: 0.8841, neg_d(sampled): 6.9977, pos_lambda: 0.7655, neg_lambda: 0.0470, best_loss: 0.2337
# Epoch 6750/10000, Loss: 0.2339, pos_d: 0.8845, neg_d(sampled): 7.0156, pos_lambda: 0.7656, neg_lambda: 0.0466, best_loss: 0.2337
# Epoch 6775/10000, Loss: 0.2339, pos_d: 0.8849, neg_d(sampled): 7.0077, pos_lambda: 0.7658, neg_lambda: 0.0466, best_loss: 0.2337
# Epoch 6800/10000, Loss: 0.2341, pos_d: 0.8852, neg_d(sampled): 7.0219, pos_lambda: 0.7658, neg_lambda: 0.0468, best_loss: 0.2337
# Epoch 6825/10000, Loss: 0.2340, pos_d: 0.8857, neg_d(sampled): 7.0161, pos_lambda: 0.7658, neg_lambda: 0.0467, best_loss: 0.2337
# Epoch 6850/10000, Loss: 0.2340, pos_d: 0.8860, neg_d(sampled): 7.0267, pos_lambda: 0.7659, neg_lambda: 0.0467, best_loss: 0.2337
# Epoch 6875/10000, Loss: 0.2340, pos_d: 0.8864, neg_d(sampled): 7.0234, pos_lambda: 0.7658, neg_lambda: 0.0467, best_loss: 0.2337
# Epoch 6900/10000, Loss: 0.2338, pos_d: 0.8868, neg_d(sampled): 7.0358, pos_lambda: 0.7661, neg_lambda: 0.0464, best_loss: 0.2337
# Epoch 6925/10000, Loss: 0.2339, pos_d: 0.8871, neg_d(sampled): 7.0390, pos_lambda: 0.7663, neg_lambda: 0.0465, best_loss: 0.2337
# Epoch 6950/10000, Loss: 0.2342, pos_d: 0.8874, neg_d(sampled): 7.0342, pos_lambda: 0.7665, neg_lambda: 0.0469, best_loss: 0.2337
# Epoch 6975/10000, Loss: 0.2338, pos_d: 0.8878, neg_d(sampled): 7.0415, pos_lambda: 0.7663, neg_lambda: 0.0464, best_loss: 0.2337
# Epoch 7000/10000, Loss: 0.2340, pos_d: 0.8881, neg_d(sampled): 7.0430, pos_lambda: 0.7665, neg_lambda: 0.0466, best_loss: 0.2337
# Epoch 7025/10000, Loss: 0.2338, pos_d: 0.8885, neg_d(sampled): 7.0490, pos_lambda: 0.7666, neg_lambda: 0.0464, best_loss: 0.2337
# Epoch 7050/10000, Loss: 0.2341, pos_d: 0.8888, neg_d(sampled): 7.0540, pos_lambda: 0.7668, neg_lambda: 0.0468, best_loss: 0.2337
# Epoch 7075/10000, Loss: 0.2338, pos_d: 0.8892, neg_d(sampled): 7.0589, pos_lambda: 0.7665, neg_lambda: 0.0464, best_loss: 0.2337
# Epoch 7100/10000, Loss: 0.2340, pos_d: 0.8895, neg_d(sampled): 7.0602, pos_lambda: 0.7668, neg_lambda: 0.0466, best_loss: 0.2337
# Epoch 7125/10000, Loss: 0.2338, pos_d: 0.8898, neg_d(sampled): 7.0605, pos_lambda: 0.7669, neg_lambda: 0.0464, best_loss: 0.2337
# Epoch 7150/10000, Loss: 0.2340, pos_d: 0.8901, neg_d(sampled): 7.0655, pos_lambda: 0.7672, neg_lambda: 0.0466, best_loss: 0.2337
# Epoch 7175/10000, Loss: 0.2339, pos_d: 0.8904, neg_d(sampled): 7.0698, pos_lambda: 0.7672, neg_lambda: 0.0465, best_loss: 0.2336
# Epoch 7200/10000, Loss: 0.2340, pos_d: 0.8906, neg_d(sampled): 7.0710, pos_lambda: 0.7674, neg_lambda: 0.0466, best_loss: 0.2336
# Epoch 7225/10000, Loss: 0.2338, pos_d: 0.8909, neg_d(sampled): 7.0738, pos_lambda: 0.7675, neg_lambda: 0.0464, best_loss: 0.2336
# Epoch 7250/10000, Loss: 0.2337, pos_d: 0.8912, neg_d(sampled): 7.0802, pos_lambda: 0.7676, neg_lambda: 0.0463, best_loss: 0.2336
# Epoch 7275/10000, Loss: 0.2342, pos_d: 0.8915, neg_d(sampled): 7.0836, pos_lambda: 0.7675, neg_lambda: 0.0468, best_loss: 0.2335
# Epoch 7300/10000, Loss: 0.2340, pos_d: 0.8919, neg_d(sampled): 7.0849, pos_lambda: 0.7674, neg_lambda: 0.0466, best_loss: 0.2335
# Epoch 7325/10000, Loss: 0.2339, pos_d: 0.8922, neg_d(sampled): 7.0964, pos_lambda: 0.7677, neg_lambda: 0.0464, best_loss: 0.2335
# Epoch 7350/10000, Loss: 0.2337, pos_d: 0.8924, neg_d(sampled): 7.0903, pos_lambda: 0.7679, neg_lambda: 0.0463, best_loss: 0.2335
# Epoch 7375/10000, Loss: 0.2337, pos_d: 0.8927, neg_d(sampled): 7.0953, pos_lambda: 0.7679, neg_lambda: 0.0462, best_loss: 0.2335
# Epoch 7400/10000, Loss: 0.2341, pos_d: 0.8930, neg_d(sampled): 7.0986, pos_lambda: 0.7680, neg_lambda: 0.0467, best_loss: 0.2335
# Epoch 7425/10000, Loss: 0.2342, pos_d: 0.8933, neg_d(sampled): 7.0976, pos_lambda: 0.7679, neg_lambda: 0.0467, best_loss: 0.2335
# Epoch 7450/10000, Loss: 0.2335, pos_d: 0.8936, neg_d(sampled): 7.1043, pos_lambda: 0.7681, neg_lambda: 0.0459, best_loss: 0.2335
# Epoch 7475/10000, Loss: 0.2339, pos_d: 0.8939, neg_d(sampled): 7.1004, pos_lambda: 0.7681, neg_lambda: 0.0464, best_loss: 0.2335
# Epoch 7500/10000, Loss: 0.2338, pos_d: 0.8941, neg_d(sampled): 7.1132, pos_lambda: 0.7682, neg_lambda: 0.0462, best_loss: 0.2335
# Epoch 7525/10000, Loss: 0.2339, pos_d: 0.8944, neg_d(sampled): 7.1122, pos_lambda: 0.7683, neg_lambda: 0.0464, best_loss: 0.2335
# Epoch 7550/10000, Loss: 0.2337, pos_d: 0.8947, neg_d(sampled): 7.1163, pos_lambda: 0.7683, neg_lambda: 0.0462, best_loss: 0.2334
# Epoch 7575/10000, Loss: 0.2336, pos_d: 0.8949, neg_d(sampled): 7.1278, pos_lambda: 0.7685, neg_lambda: 0.0461, best_loss: 0.2334
# Epoch 7600/10000, Loss: 0.2340, pos_d: 0.8952, neg_d(sampled): 7.1186, pos_lambda: 0.7687, neg_lambda: 0.0465, best_loss: 0.2334
# Epoch 7625/10000, Loss: 0.2339, pos_d: 0.8955, neg_d(sampled): 7.1187, pos_lambda: 0.7686, neg_lambda: 0.0464, best_loss: 0.2334
# Epoch 7650/10000, Loss: 0.2338, pos_d: 0.8957, neg_d(sampled): 7.1280, pos_lambda: 0.7685, neg_lambda: 0.0462, best_loss: 0.2334
# Epoch 7675/10000, Loss: 0.2340, pos_d: 0.8959, neg_d(sampled): 7.1239, pos_lambda: 0.7688, neg_lambda: 0.0465, best_loss: 0.2334
# Epoch 7700/10000, Loss: 0.2338, pos_d: 0.8961, neg_d(sampled): 7.1275, pos_lambda: 0.7689, neg_lambda: 0.0463, best_loss: 0.2334
# Epoch 7725/10000, Loss: 0.2338, pos_d: 0.8963, neg_d(sampled): 7.1391, pos_lambda: 0.7688, neg_lambda: 0.0462, best_loss: 0.2334
# Early stopping at epoch 7733
# Final node embeddings (Z):
#  [[-5.954956   -1.2339189 ]
#  [-0.03892604  7.3834124 ]
#  [-5.1946874   0.11561096]
#  ...
#  [-0.6337813   1.0021245 ]
#  [ 0.65790635 -1.9389153 ]
#  [-3.5215883   4.2302604 ]]

# %%
# Debugging / teaching cell.
# This walks through how the indexing works when we move from
# pair-index space -> node-index space -> embedding space.
print("=== Base tensors ===")
print("A shape:", tuple(A_tensor.shape))
print("Z shape:", tuple(Z.shape))
print("gamma shape:", tuple(gamma.shape))
print("i shape:", tuple(i.shape), "j shape:", tuple(j.shape))
print("pair_targets shape:", tuple(pair_targets.shape))
print("pos_idx shape:", tuple(pos_idx.shape), "neg_idx shape:", tuple(neg_idx.shape))

print("\n=== Positive pairs indexing ===")
# ipos and jpos contain the node ids for every positive pair.
ipos = i[pos_idx]
jpos = j[pos_idx]
print("i[pos_idx] shape:", tuple(ipos.shape))
print("j[pos_idx] shape:", tuple(jpos.shape))

# Fancy indexing into Z returns one latent vector per endpoint per positive pair.
Z_i_pos = Z[ipos]
Z_j_pos = Z[jpos]
print("Z[i[pos_idx]] shape:", tuple(Z_i_pos.shape))
print("Z[j[pos_idx]] shape:", tuple(Z_j_pos.shape))

# Subtracting the endpoint embeddings gives pairwise displacement vectors in latent space.
delta_pos = Z_i_pos - Z_j_pos
print("Z[i[pos_idx]] - Z[j[pos_idx]] shape:", tuple(delta_pos.shape))

# Taking the norm over the latent dimension collapses each vector down to one scalar distance.
pos_dist_dbg = torch.norm(delta_pos, dim=1)
print("torch.norm(..., dim=1) shape:", tuple(pos_dist_dbg.shape))

print("\n=== Negative sampled pairs indexing ===")
# Repeat the same logic for a tiny random sample of non-edges so the dimensions are easy to inspect.
neg_pick_dbg = torch.randint(0, num_neg_total, (min(10, num_neg_sample),), device=Z.device)
neg_sample_idx_dbg = neg_idx[neg_pick_dbg]
print("neg_pick_dbg shape:", tuple(neg_pick_dbg.shape))
print("neg_sample_idx_dbg shape:", tuple(neg_sample_idx_dbg.shape))

ineg = i[neg_sample_idx_dbg]
jneg = j[neg_sample_idx_dbg]
print("i[neg_sample_idx_dbg] shape:", tuple(ineg.shape))
print("j[neg_sample_idx_dbg] shape:", tuple(jneg.shape))

neg_dist_dbg = torch.norm(Z[ineg] - Z[jneg], dim=1)
print("neg_dist_dbg shape:", tuple(neg_dist_dbg.shape))

print("\n=== First 5 positive pair mappings (pair_index -> (node_i, node_j)) ===")
k = min(5, pos_idx.numel())
for t in range(k):
    pair_k = int(pos_idx[t].item())
    node_i = int(i[pair_k].item())
    node_j = int(j[pair_k].item())
    print(f"pair idx {pair_k} -> ({node_i}, {node_j})")

# gamma lives at the node level, so it must be broadcast to the pair level
# before it can be combined with pair distances in the Poisson log-rate.
if gamma.ndim == 1 and gamma.shape[0] == n:
    pos_gamma_dbg = gamma[ipos] + gamma[jpos]
    print("\npos_gamma (gamma[i[pos_idx]] + gamma[j[pos_idx]]) shape:", tuple(pos_gamma_dbg.shape))
    print("Matches pos_dist shape:", tuple(pos_gamma_dbg.shape) == tuple(pos_dist_dbg.shape))
# Out:
# === Base tensors ===
# A shape: (14000, 14000)
# Z shape: (14000, 2)
# gamma shape: (14000,)
# i shape: (97993000,) j shape: (97993000,)
# pair_targets shape: (97993000,)
# pos_idx shape: (152893,) neg_idx shape: (97840107,)
#
# === Positive pairs indexing ===
# i[pos_idx] shape: (152893,)
# j[pos_idx] shape: (152893,)
# Z[i[pos_idx]] shape: (152893, 2)
# Z[j[pos_idx]] shape: (152893, 2)
# Z[i[pos_idx]] - Z[j[pos_idx]] shape: (152893, 2)
# torch.norm(..., dim=1) shape: (152893,)
#
# === Negative sampled pairs indexing ===
# neg_pick_dbg shape: (10,)
# neg_sample_idx_dbg shape: (10,)
# i[neg_sample_idx_dbg] shape: (10,)
# j[neg_sample_idx_dbg] shape: (10,)
# neg_dist_dbg shape: (10,)
#
# === First 5 positive pair mappings (pair_index -> (node_i, node_j)) ===
# pair idx 35 -> (0, 36)
# pair idx 282 -> (0, 283)
# pair idx 1373 -> (0, 1374)
# pair idx 2002 -> (0, 2003)
# pair idx 2785 -> (0, 2786)
#
# pos_gamma (gamma[i[pos_idx]] + gamma[j[pos_idx]]) shape: (152893,)
# Matches pos_dist shape: True

# %%
# Final diagnostic pass over every unordered pair in the graph.
# If training worked, true edges should on average have smaller latent distances
# and therefore larger Poisson rates than non-edges.
with torch.no_grad():
    # Full pairwise distance matrix in the learned latent space.
    final_dist = torch.cdist(Z, Z, p=2)
    pair_dist = final_dist[i, j]

    # Rebuild lambda_ij for every unordered pair, not just the sampled negatives.
    pair_gamma = gamma[i] + gamma[j]
    pair_raw = pair_gamma - pair_dist
    pair_lambda = torch.exp(pair_raw)

    pos_mask = pair_targets == 1
    neg_mask = pair_targets == 0

    print("mean distance (edge=1):", pair_dist[pos_mask].mean().item())
    print("mean distance (edge=0):", pair_dist[neg_mask].mean().item())
    print("mean lambda (edge=1):", pair_lambda[pos_mask].mean().item())
    print("mean lambda (edge=0):", pair_lambda[neg_mask].mean().item())

    # Optional interpretation for binary links under a Poisson model:
    # P(edge exists) = P(Y > 0) = 1 - exp(-lambda).
    #pair_p_link = 1.0 - torch.exp(-pair_lambda)
    #print("mean predicted p(link) for true edges:", pair_p_link[pos_mask].mean().item())
    #print("mean predicted p(link) for non-edges:", pair_p_link[neg_mask].mean().item())
# Out:
# mean distance (edge=1): 0.8964279890060425
# mean distance (edge=0): 7.135520935058594
# mean lambda (edge=1): 0.7687940001487732
# mean lambda (edge=0): 0.04615504667162895

# %%
import matplotlib.pyplot as plt

# Plot the learned 2D latent positions directly.
# Points that end up near each other are pairs the model finds more compatible.
Z_np = Z.detach().cpu().numpy()

plt.figure(figsize=(8, 6))
if "y" in globals() and y is not None:
    # When labels exist (MNIST), color points by digit so we can inspect whether
    # the learned geometry also lines up with semantic structure.
    labels = y.detach().cpu().numpy() if torch.is_tensor(y) else np.asarray(y)
    scatter = plt.scatter(
        Z_np[:, 0],
        Z_np[:, 1],
        c=labels,
        cmap="tab10",
        s=8,
        alpha=0.75,
    )
    plt.colorbar(scatter, ticks=range(10), label="Digit label")
else:
    # Unlabeled synthetic data: just show the geometry.
    plt.scatter(Z_np[:, 0], Z_np[:, 1], s=8, alpha=0.75)

plt.title("Final 2D Z embeddings")
plt.xlabel("Z1")
plt.ylabel("Z2")
plt.axis("equal")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This last figure studies the Poisson loss itself in a simplified 2-variable setting.
# x = distance for a positive pair, y = distance for a negative pair.
x = np.linspace(0.0, 10.0, 250)
y = np.linspace(0.0, 10.0, 250)
X, Y = np.meshgrid(x, y)

# Use average learned gamma values if they exist, so the toy loss surface roughly
# matches the scale of the fitted model.
if "gamma" in globals() and "ipos" in globals() and "jpos" in globals() and "ineg" in globals() and "jneg" in globals():
    gamma_pos_value = float((gamma[ipos] + gamma[jpos]).mean().detach().cpu().item())
    gamma_neg_value = float((gamma[ineg] + gamma[jneg]).mean().detach().cpu().item())
elif "gamma" in globals():
    gamma_mean = float(gamma.detach().cpu().mean().item()) if hasattr(gamma, "detach") else float(np.mean(gamma))
    gamma_pos_value = 2.0 * gamma_mean
    gamma_neg_value = 2.0 * gamma_mean
else:
    gamma_pos_value = 0.0
    gamma_neg_value = 0.0

# Apply the same latent-distance Poisson rate formula used during training.
lambda_pos = np.exp(gamma_pos_value - X)
lambda_neg = np.exp(gamma_neg_value - Y)

# Negative log-likelihood for one positive observation (y=1) and one negative observation (y=0):
#   L = -(1 * log(lambda_pos) - lambda_pos) - (0 * log(lambda_neg) - lambda_neg)
#     = -log(lambda_pos) + lambda_pos + lambda_neg
L = -np.log(lambda_pos) + lambda_pos + lambda_neg

# Numerical gradients show which direction gradient descent would move the two distances.
step_x = x[1] - x[0]
step_y = y[1] - y[0]
dL_dy, dL_dx = np.gradient(L, step_y, step_x)
grad_norm = np.sqrt(dL_dx**2 + dL_dy**2)

fig, axes = plt.subplots(1, 2, figsize=(14, 5.5))

# Left: the loss surface together with the negative gradient field.
# Arrows indicate the local update direction for gradient descent.
contour = axes[0].contourf(X, Y, L, levels=40, cmap="viridis")
fig.colorbar(contour, ax=axes[0], label="Loss value")

stride = 12
axes[0].quiver(
    X[::stride, ::stride],
    Y[::stride, ::stride],
    -dL_dx[::stride, ::stride],
    -dL_dy[::stride, ::stride],
    color="white",
    alpha=0.75,
    scale=35,
    width=0.003,
)
axes[0].set_xlabel("positive distance (x)")
axes[0].set_ylabel("negative distance (y)")
axes[0].set_title(
    f"Poisson NLL + descent (gamma_pos={gamma_pos_value:.3f}, gamma_neg={gamma_neg_value:.3f})"
)

# Right: how steep the loss is at each point.
grad_map = axes[1].contourf(X, Y, grad_norm, levels=40, cmap="magma")
fig.colorbar(grad_map, ax=axes[1], label="|grad L|")
axes[1].set_xlabel("positive distance (x)")
axes[1].set_ylabel("negative distance (y)")
axes[1].set_title("Gradient magnitude")

plt.tight_layout()
plt.show()
